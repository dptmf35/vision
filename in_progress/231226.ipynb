# %%
import cv2
import matplotlib.pyplot as plt



im1 = cv2.imread("./data/test2/2023-12-21-174235.jpg")
im2 = cv2.imread("./data/test2/2023-12-21-174239.jpg")
im3 = cv2.imread("./data/test2/2023-12-21-174244.jpg")
im4 = cv2.imread("./data/test2/2023-12-21-174248.jpg")
im5 = cv2.imread("./data/test2/2023-12-21-174252.jpg")
im6 = cv2.imread("./data/test2/2023-12-21-174303.jpg")
im7 = cv2.imread("./data/test2/2023-12-21-174415.jpg")
im8 = cv2.imread("./data/test2/2023-12-21-174430.jpg")
im9 = cv2.imread("./data/test2/2023-12-21-174433.jpg")
im10 = cv2.imread("./data/test2/2023-12-21-174438.jpg")

# %%
im1_rotate = cv2.rotate(im1, cv2.ROTATE_90_CLOCKWISE)
im2_rotate = cv2.rotate(im2, cv2.ROTATE_90_CLOCKWISE)
im3_rotate = cv2.rotate(im3, cv2.ROTATE_90_CLOCKWISE)
im4_rotate = cv2.rotate(im4, cv2.ROTATE_90_CLOCKWISE)
im5_rotate = cv2.rotate(im5, cv2.ROTATE_90_CLOCKWISE)
im6_rotate = cv2.rotate(im6, cv2.ROTATE_90_CLOCKWISE)
im7_rotate = cv2.rotate(im7, cv2.ROTATE_90_CLOCKWISE)
im8_rotate = cv2.rotate(im8, cv2.ROTATE_90_CLOCKWISE)
im9_rotate = cv2.rotate(im9, cv2.ROTATE_90_CLOCKWISE)
im10_rotate = cv2.rotate(im10, cv2.ROTATE_90_CLOCKWISE)


# plt.imshow(im1_rotate, cmap='gray')

# %%
im1_gray = cv2.cvtColor(im1_rotate, cv2.COLOR_BGR2GRAY)
im2_gray = cv2.cvtColor(im2_rotate, cv2.COLOR_BGR2GRAY)
im3_gray = cv2.cvtColor(im3_rotate, cv2.COLOR_BGR2GRAY)
im4_gray = cv2.cvtColor(im4_rotate, cv2.COLOR_BGR2GRAY)
im5_gray = cv2.cvtColor(im5_rotate, cv2.COLOR_BGR2GRAY)
im6_gray = cv2.cvtColor(im6_rotate, cv2.COLOR_BGR2GRAY)
im7_gray = cv2.cvtColor(im7_rotate, cv2.COLOR_BGR2GRAY)
im8_gray = cv2.cvtColor(im8_rotate, cv2.COLOR_BGR2GRAY)
im9_gray = cv2.cvtColor(im9_rotate, cv2.COLOR_BGR2GRAY)
im10_gray = cv2.cvtColor(im10_rotate, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(15, 15))

plt.subplot(221)
plt.imshow(im1_gray, cmap='gray')

plt.subplot(222)
plt.imshow(im2_gray, cmap='gray')


plt.subplot(223)
plt.imshow(im3_gray, cmap='gray')


plt.subplot(224)
plt.imshow(im4_gray, cmap='gray')

# %%
plt.imshow(im5_gray, cmap='gray')

# %%
def calculate_metrics(gt, edge_detected):
    TP = np.sum((gt == 255) & (edge_detected == 255))
    FP = np.sum((gt == 0) & (edge_detected == 255))
    FN = np.sum((gt == 255) & (edge_detected == 0))
    # 실제 에지 중에서 에지 검출 알고리즘이 올바르게 식별한 에지의 비율
    recall = TP / (TP + FN) if (TP + FN) != 0 else 0
    # 알고리즘이 '에지'라고 분류한 것들 중 실제로 에지인 것의 비율
    precision = TP / (TP + FP) if (TP + FP) != 0 else 0

    return recall, precision

# %% [markdown]
# ---
# ## Default

# %%
def canny_default(img_gray) :
    blurred = cv2.GaussianBlur(img_gray, (3, 3), 0)
    edge = cv2.Canny(blurred, 40, 120)
    return edge

# %%
im1_edge = canny_default(im1_gray)
im2_edge = canny_default(im2_gray)
im3_edge = canny_default(im3_gray)
im4_edge = canny_default(im4_gray)
im5_edge = canny_default(im5_gray)
im6_edge = canny_default(im6_gray)
im7_edge = canny_default(im7_gray)
im8_edge = canny_default(im8_gray)
im9_edge = canny_default(im9_gray)
im10_edge = canny_default(im10_gray)

# %%
print("Recall And Precision")
print("GT(Edge 1) / Edge 2",calculate_metrics(im1_edge, im2_edge))
print("GT(Edge 1) / Edge 3",calculate_metrics(im1_edge, im3_edge))
print("GT(Edge 1) / Edge 4",calculate_metrics(im1_edge, im4_edge))
print("GT(Edge 1) / Edge 5",calculate_metrics(im1_edge, im5_edge))
print("GT(Edge 1) / Edge 6",calculate_metrics(im1_edge, im6_edge))
print("GT(Edge 1) / Edge 7",calculate_metrics(im1_edge, im7_edge))
print("GT(Edge 1) / Edge 8",calculate_metrics(im1_edge, im8_edge))
print("GT(Edge 1) / Edge 9",calculate_metrics(im1_edge, im9_edge))
print("GT(Edge 1) / Edge 10",calculate_metrics(im1_edge, im10_edge))
# Out:
# Recall And Precision
# GT(Edge 1) / Edge 2 (0.6580574754456165, 0.7665254237288136)
# GT(Edge 1) / Edge 3 (0.4314296107675518, 0.5511152416356877)
# GT(Edge 1) / Edge 4 (0.00672971989814478, 0.2890625)
# GT(Edge 1) / Edge 5 (0.008002910149145144, 0.18723404255319148)
# GT(Edge 1) / Edge 6 (0.5492906511458713, 0.5608170844939647)
# GT(Edge 1) / Edge 7 (0.022189887231720627, 0.1641991924629879)
# GT(Edge 1) / Edge 8 (0.020189159694434338, 0.11538461538461539)
# GT(Edge 1) / Edge 9 (0.029101491451436885, 0.12403100775193798)
# GT(Edge 1) / Edge 10 (0.029283375773008366, 0.06764705882352941)

# %%
im1_blurred = cv2.GaussianBlur(im1_gray, (3, 3), 0)
im1_edge = cv2.Canny(im1_blurred, 40, 120)
plt.figure(figsize=(10, 10))
plt.imshow(im1_edge, cmap='gray')

# %%
im2_blurred = cv2.GaussianBlur(im2_gray, (3, 3), 0)
im2_edge = cv2.Canny(im2_blurred, 40, 120)
plt.figure(figsize=(10, 10))
plt.imshow(im2_edge, cmap='gray')

# %%
im3_blurred = cv2.GaussianBlur(im3_gray, (3, 3), 0)
im3_edge = cv2.Canny(im3_blurred, 40, 120)
plt.figure(figsize=(10, 10))
plt.imshow(im3_edge, cmap='gray')

# %%
im4_blurred = cv2.GaussianBlur(im4_gray, (3, 3), 0)
im4_edge = cv2.Canny(im4_blurred, 40, 120)
plt.figure(figsize=(10, 10))
plt.imshow(im4_edge, cmap='gray')

# %%
im5_blurred = cv2.GaussianBlur(im5_gray, (3, 3), 0)
im5_edge = cv2.Canny(im5_blurred, 40, 120)
plt.figure(figsize=(10, 10))
plt.imshow(im5_edge, cmap='gray')

# %%
# autocanny 
import numpy as np

def auto_canny(img, sigma=0.33) : 
    img = cv2.GaussianBlur(img, (5, 5), 0)
    v = np.median(img)
#     print(f"Average brightness:{np.mean(img):.2f}") # 평균 밝기 계산 
#     print(f"Bright Contrast:{np.std(img):.2f}") # 대조 값
    lower = int(max(0, 1.0 - sigma)*v)
    upper = int(min(255, (1.0 + sigma)*v ))
    print(f"Threshold (lower) {lower} (upper) {upper}")
    edged = cv2.Canny(img, lower, upper)
    return edged

im4_edged = auto_canny(im4_gray)
plt.imshow(im4_edged, cmap='gray')
# Out:
# Threshold (lower) 14 (upper) 29

# %%
im5_edged = auto_canny(im5_gray)
plt.imshow(im5_edged, cmap='gray')
# Out:
# Threshold (lower) 14 (upper) 29

# %%
calculate_metrics(im1_edge, im2_edge)
# Out:
# (0.6580574754456165, 0.7665254237288136)

# %%
calculate_metrics(im1_edge, im3_edge)
# Out:
# (0.4314296107675518, 0.5511152416356877)

# %%
im1_edge = auto_canny(im1_gray)
im2_edge = auto_canny(im2_gray)
im3_edge = auto_canny(im3_gray)
im4_edge = auto_canny(im4_gray)
im5_edge = auto_canny(im5_gray)
im6_edge = auto_canny(im6_gray)
im7_edge = auto_canny(im7_gray)
im8_edge = auto_canny(im8_gray)
im9_edge = auto_canny(im9_gray)
im10_edge = auto_canny(im10_gray)
# Out:
# Threshold (lower) 106 (upper) 211
# Threshold (lower) 96 (upper) 191
# Threshold (lower) 71 (upper) 142
# Threshold (lower) 14 (upper) 29
# Threshold (lower) 17 (upper) 34
# Threshold (lower) 105 (upper) 208
# Threshold (lower) 24 (upper) 49
# Threshold (lower) 32 (upper) 63
# Threshold (lower) 36 (upper) 73
# Threshold (lower) 31 (upper) 62

# %%
print("Recall And Precision")
print("GT(Edge 1) / Edge 2",calculate_metrics(im1_edge, im2_edge))
print("GT(Edge 1) / Edge 3",calculate_metrics(im1_edge, im3_edge))
print("GT(Edge 1) / Edge 4",calculate_metrics(im1_edge, im4_edge))
print("GT(Edge 1) / Edge 5",calculate_metrics(im1_edge, im5_edge))
print("GT(Edge 1) / Edge 6",calculate_metrics(im1_edge, im6_edge))
print("GT(Edge 1) / Edge 7",calculate_metrics(im1_edge, im7_edge))
print("GT(Edge 1) / Edge 8",calculate_metrics(im1_edge, im8_edge))
print("GT(Edge 1) / Edge 9",calculate_metrics(im1_edge, im9_edge))
print("GT(Edge 1) / Edge 10",calculate_metrics(im1_edge, im10_edge))
# Out:
# Recall And Precision
# GT(Edge 1) / Edge 2 (0.7693823915900131, 0.6820034944670937)
# GT(Edge 1) / Edge 3 (0.6734559789750328, 0.3497099965881952)
# GT(Edge 1) / Edge 4 (0.12220762155059132, 0.3563218390804598)
# GT(Edge 1) / Edge 5 (0.4454664914586071, 0.3985890652557319)
# GT(Edge 1) / Edge 6 (0.6320630749014454, 0.5503432494279176)
# GT(Edge 1) / Edge 7 (0.08935611038107753, 0.06772908366533864)
# GT(Edge 1) / Edge 8 (0.08607095926412615, 0.06247019551740582)
# GT(Edge 1) / Edge 9 (0.08672798948751642, 0.053833605220228384)
# GT(Edge 1) / Edge 10 (0.07752956636005257, 0.032100108813928184)

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## AutoCanny

# %%
im1_edge = auto_canny(im1_gray)
im2_edge = auto_canny(im2_gray)
im3_edge = auto_canny(im3_gray)

print(calculate_metrics(im1_edge, im2_edge))
print(calculate_metrics(im1_edge, im3_edge))
# Out:
# Threshold (lower) 106 (upper) 211
# Threshold (lower) 96 (upper) 191
# Threshold (lower) 71 (upper) 142
# (0.7693823915900131, 0.6820034944670937)
# (0.6734559789750328, 0.3497099965881952)

# %%
plt.figure(figsize=(10, 10))
plt.subplot(131)
plt.imshow(im1_edge, cmap='gray')

plt.subplot(132)
plt.imshow(im2_edge, cmap='gray')

plt.subplot(133)
plt.imshow(im3_edge, cmap='gray')

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Histogram Equalization

# %%
im1_eq = cv2.equalizeHist(im1_gray)
im2_eq = cv2.equalizeHist(im2_gray)
im3_eq = cv2.equalizeHist(im3_gray)
im4_eq = cv2.equalizeHist(im4_gray)

# %%
im1_edge = cv2.Canny(im1_eq, 100, 200)
plt.figure(figsize=(10, 10))
plt.imshow(im1_edge, cmap='gray')

# %% [markdown]
# ---

# %% [markdown]
# ## WeightedGrad

# %%
def calculate_weighted_gradient(image):
    # 색상 채널 분리
    blue, green, red = cv2.split(image)

    # Sobel 연산자를 각 채널에 적용하여 그래디언트 계산
    grad_x_red = cv2.Sobel(red, cv2.CV_64F, 1, 0, ksize=3)
    grad_y_red = cv2.Sobel(red, cv2.CV_64F, 0, 1, ksize=3)
    
    grad_x_green = cv2.Sobel(green, cv2.CV_64F, 1, 0, ksize=3)
    grad_y_green = cv2.Sobel(green, cv2.CV_64F, 0, 1, ksize=3)
    
    grad_x_blue = cv2.Sobel(blue, cv2.CV_64F, 1, 0, ksize=3)
    grad_y_blue = cv2.Sobel(blue, cv2.CV_64F, 0, 1, ksize=3)

    # 각 채널에 대한 그래디언트 크기 계산
    magnitude_red = np.sqrt(grad_x_red**2 + grad_y_red**2)
    magnitude_green = np.sqrt(grad_x_green**2 + grad_y_green**2)
    magnitude_blue = np.sqrt(grad_x_blue**2 + grad_y_blue**2)

    # 가중치 적용 (예를 들어, 녹색 채널에 더 큰 가중치)
    weighted_magnitude = 0.1 * magnitude_red + 0.6 * magnitude_green + 0.2 * magnitude_blue

     # Canny 엣지 검출을 위한 임계값 설정
    lower_threshold = 100  # 임계값을 조정하여 엣지를 더 진하게 만들 수 있습니다.
    upper_threshold = 200
    blurred = cv2.GaussianBlur(weighted_magnitude, (5, 5), 0)
    # Canny 엣지 검출 적용
    edges = cv2.Canny(blurred.astype(np.uint8), lower_threshold, upper_threshold)

    return edges

# %%
im1_edge = calculate_weighted_gradient(im1_rotate)
im2_edge = calculate_weighted_gradient(im2_rotate)
im3_edge = calculate_weighted_gradient(im3_rotate)
im4_edge = calculate_weighted_gradient(im4_rotate)
im5_edge = calculate_weighted_gradient(im5_rotate)
im6_edge = calculate_weighted_gradient(im6_rotate)
im7_edge = calculate_weighted_gradient(im7_rotate)
im8_edge = calculate_weighted_gradient(im8_rotate)
im9_edge = calculate_weighted_gradient(im9_rotate)
im10_edge = calculate_weighted_gradient(im10_rotate)

# %%
print("Recall And Precision")
print("GT(Edge 1) / Edge 2",calculate_metrics(im1_edge, im2_edge))
print("GT(Edge 1) / Edge 3",calculate_metrics(im1_edge, im3_edge))
print("GT(Edge 1) / Edge 4",calculate_metrics(im1_edge, im4_edge))
print("GT(Edge 1) / Edge 5",calculate_metrics(im1_edge, im5_edge))
print("GT(Edge 1) / Edge 6",calculate_metrics(im1_edge, im6_edge))
print("GT(Edge 1) / Edge 7",calculate_metrics(im1_edge, im7_edge))
print("GT(Edge 1) / Edge 8",calculate_metrics(im1_edge, im8_edge))
print("GT(Edge 1) / Edge 9",calculate_metrics(im1_edge, im9_edge))
print("GT(Edge 1) / Edge 10",calculate_metrics(im1_edge, im10_edge))
# Out:
# Recall And Precision
# GT(Edge 1) / Edge 2 (0.712953123155036, 0.736970584645429)
# GT(Edge 1) / Edge 3 (0.4989963395914512, 0.5943741209563994)
# GT(Edge 1) / Edge 4 (0.013578934939189987, 0.5275229357798165)
# GT(Edge 1) / Edge 5 (0.015940488841657812, 0.37815126050420167)
# GT(Edge 1) / Edge 6 (0.538788522848034, 0.5204745066727501)
# GT(Edge 1) / Edge 7 (0.022198606683197543, 0.17013574660633485)
# GT(Edge 1) / Edge 8 (0.023261305939308065, 0.09869739478957916)
# GT(Edge 1) / Edge 9 (0.03648600779312788, 0.11000355998576006)
# GT(Edge 1) / Edge 10 (0.05041917581768804, 0.08361073037008028)

# %%
im1_edge = calculate_weighted_gradient(im1_rotate)
plt.figure(figsize=(10, 10))
plt.imshow(im1_edge, cmap='gray')

# %%
im1_erode = cv2.erode(im1_edge, kernel=(5,5), iterations=1)

plt.figure(figsize=(10, 10))
plt.imshow(im1_erode, cmap='gray')

# %%
im2_edge = calculate_weighted_gradient(im2_rotate)
plt.figure(figsize=(10, 10))
plt.imshow(im2_edge, cmap='gray')

# %%
im3_edge = calculate_weighted_gradient(im3_rotate)
plt.figure(figsize=(10, 10))
plt.imshow(im3_edge, cmap='gray')

# %%
calculate_metrics(im1_edge, im2_edge)
# Out:
# (0.712953123155036, 0.736970584645429)

# %%
calculate_metrics(im1_edge, im3_edge)
# Out:
# (0.4989963395914512, 0.5943741209563994)

# %%
img = im1_rotate.copy()

lines = cv2.HoughLines(im1_edge, 1, np.pi / 180, threshold=120)

horizontal_lines = []
vertical_lines = []
if lines is not None:
    for rho, theta in lines[:, 0]:
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a * rho
        y0 = b * rho
        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))

        # 각도를 기준으로 수평선과 수직선을 분류
        if theta < np.pi / 4 or theta > 3 * np.pi / 4:  # 수직선
            vertical_lines.append((x1, y1, x2, y2))
            cv2.line(img, (x1, y1), (x2, y2), (255, 0, 0), 2)
        elif np.pi / 4 <= theta <= 3 * np.pi / 4:  # 수평선
            horizontal_lines.append((x1, y1, x2, y2))
            cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = im1_rotate.copy()

lines = cv2.HoughLines(im1_erode, 1, np.pi / 180, threshold=150)

horizontal_lines = []
vertical_lines = []
if lines is not None:
    for rho, theta in lines[:, 0]:
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a * rho
        y0 = b * rho
        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))

        # 각도를 기준으로 수평선과 수직선을 분류
        if theta < np.pi / 4 or theta > 3 * np.pi / 4:  # 수직선
            vertical_lines.append((x1, y1, x2, y2))
            cv2.line(img, (x1, y1), (x2, y2), (255, 0, 0), 2)
        elif np.pi / 4 <= theta <= 3 * np.pi / 4:  # 수평선
            horizontal_lines.append((x1, y1, x2, y2))
            cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = im1_rotate.copy()


lines_probabilistic = cv2.HoughLinesP(im1_edge, 1, np.pi/180, 120, 
                                      minLineLength=150, maxLineGap=100)
# 확률적 허프 변환으로 찾은 직선 그리기
if lines_probabilistic is not None:
    for line in lines_probabilistic:
        x1, y1, x2, y2 = line[0]
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
# 각도 계산 함수
def calculate_angle(x1, y1, x2, y2):
    return np.arctan2(y2 - y1, x2 - x1) * 180.0 / np.pi

img = im1_rotate.copy()


lines = cv2.HoughLinesP(im1_edge, 1, np.pi/180, 120, 
                                      minLineLength=150, maxLineGap=100)

# 검출된 선분 그리기
for line in lines:
    x1, y1, x2, y2 = line[0]
    angle = calculate_angle(x1, y1, x2, y2)

    # 수직 및 수평선만 선택 (각도로 필터링)
    if -10 <= angle <= 10 or 170 <= angle <= 180 or -180 <= angle <= -170:
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
    else :
        cv2.line(img, (x1, y1), (x2, y2), (255,0, 0), 2)
        
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = im2_rotate.copy()


lines = cv2.HoughLinesP(im2_edge, 1, np.pi/180, 120, 
                                      minLineLength=150, maxLineGap=100)

# 검출된 선분 그리기
for line in lines:
    x1, y1, x2, y2 = line[0]
    angle = calculate_angle(x1, y1, x2, y2)

    # 수직 및 수평선만 선택 (각도로 필터링)
    if -10 <= angle <= 10 or 170 <= angle <= 180 or -180 <= angle <= -170:
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
    else :
        cv2.line(img, (x1, y1), (x2, y2), (255,0, 0), 2)
        
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = im3_rotate.copy()


lines = cv2.HoughLinesP(im3_edge, 1, np.pi/180, 120, 
                                      minLineLength=150, maxLineGap=100)

# 검출된 선분 그리기
for line in lines:
    x1, y1, x2, y2 = line[0]
    angle = calculate_angle(x1, y1, x2, y2)

    # 수직 및 수평선만 선택 (각도로 필터링)
    if -10 <= angle <= 10 or 170 <= angle <= 180 or -180 <= angle <= -170:
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
    else :
        cv2.line(img, (x1, y1), (x2, y2), (255,0, 0), 2)
        
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ---

# %% [markdown]
# ## Otsu

# %%
def auto_canny_otsu(image):
    # 오츠의 방법을 사용하여 엣지 검출을 위한 최적의 임계값을 계산
    high_thresh, _ = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    low_thresh = 0.5 * high_thresh

    # Canny 엣지 검출 적용
    blur = cv2.GaussianBlur(image, (3, 3), 0)
    edged = cv2.Canny(blur, low_thresh, high_thresh)

    return edged

# %%
im1_edge = auto_canny_otsu(im1_gray)
plt.figure(figsize=(10, 10))
plt.imshow(im1_edge, cmap='gray')

# %%
im2_edge = auto_canny_otsu(im2_gray)
plt.figure(figsize=(10, 10))
plt.imshow(im2_edge, cmap='gray')

# %%
im3_edge = auto_canny_otsu(im3_gray)
plt.figure(figsize=(10, 10))
plt.imshow(im3_edge, cmap='gray')

# %%
print(calculate_metrics(im1_edge, im2_edge))
print(calculate_metrics(im1_edge, im3_edge))
# Out:
# (0.7713537949083987, 0.7649834827748938)
# (0.4917915774446824, 0.5236888776285786)

# %%
im1_edge = auto_canny_otsu(im1_gray)
im2_edge = auto_canny_otsu(im2_gray)
im3_edge = auto_canny_otsu(im3_gray)
im4_edge = auto_canny_otsu(im4_gray)
im5_edge = auto_canny_otsu(im5_gray)
im6_edge = auto_canny_otsu(im6_gray)
im7_edge = auto_canny_otsu(im7_gray)
im8_edge = auto_canny_otsu(im8_gray)
im9_edge = auto_canny_otsu(im9_gray)
im10_edge = auto_canny_otsu(im10_gray)

# %%
print("Recall And Precision")
print("GT(Edge 1) / Edge 2",calculate_metrics(im1_edge, im2_edge))
print("GT(Edge 1) / Edge 3",calculate_metrics(im1_edge, im3_edge))
print("GT(Edge 1) / Edge 4",calculate_metrics(im1_edge, im4_edge))
print("GT(Edge 1) / Edge 5",calculate_metrics(im1_edge, im5_edge))
print("GT(Edge 1) / Edge 6",calculate_metrics(im1_edge, im6_edge))
print("GT(Edge 1) / Edge 7",calculate_metrics(im1_edge, im7_edge))
print("GT(Edge 1) / Edge 8",calculate_metrics(im1_edge, im8_edge))
print("GT(Edge 1) / Edge 9",calculate_metrics(im1_edge, im9_edge))
print("GT(Edge 1) / Edge 10",calculate_metrics(im1_edge, im10_edge))
# Out:
# Recall And Precision
# GT(Edge 1) / Edge 2 (0.7713537949083987, 0.7649834827748938)
# GT(Edge 1) / Edge 3 (0.4917915774446824, 0.5236888776285786)
# GT(Edge 1) / Edge 4 (0.1310968355936236, 0.18902229845626073)
# GT(Edge 1) / Edge 5 (0.2545800618605758, 0.511472275334608)
# GT(Edge 1) / Edge 6 (0.5905305733999524, 0.5829027712541099)
# GT(Edge 1) / Edge 7 (0.08565310492505353, 0.09498680738786279)
# GT(Edge 1) / Edge 8 (0.08827028313109683, 0.08211598052235503)
# GT(Edge 1) / Edge 9 (0.09826314537235308, 0.08071135430916553)
# GT(Edge 1) / Edge 10 (0.05733999524149417, 0.05231169958758411)

# %%
img = im1_rotate.copy()


lines = cv2.HoughLinesP(im1_edge, 1, np.pi/180, 100, 
                                      minLineLength=150, maxLineGap=100)

# 검출된 선분 그리기
for line in lines:
    x1, y1, x2, y2 = line[0]
    angle = calculate_angle(x1, y1, x2, y2)

    # 수직 및 수평선만 선택 (각도로 필터링)
    if -10 <= angle <= 10 or 170 <= angle <= 180 or -180 <= angle <= -170:
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
    else :
        cv2.line(img, (x1, y1), (x2, y2), (255,0, 0), 2)

plt.figure(figsize=(7, 10))

plt.subplot(131)
plt.imshow(im1_gray, cmap='gray')

plt.subplot(132)
plt.imshow(im1_edge, cmap='gray')


plt.subplot(133)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 체커보드 사진 촬영

# %%
import time 
cap = cv2.VideoCapture("http://192.168.0.9:4747/video")
# 저장할 이미지의 인덱스
img_index = 0

# 이전에 프레임을 저장한 시간
prev_time = 0
while cap.isOpened() :
    
    ret, frame = cap.read()
    
    if not ret:
        break

    # 현재 시간
    current_time = time.time()

    # 1초마다 이미지 저장
    if current_time - prev_time >= 1:
        img_name = f"./data/droid_calib/checkerboard_{img_index}.jpg"
        cv2.imwrite(img_name, frame)
        print(f"Saved {img_name}")
        img_index += 1
        prev_time = current_time

# 자원 해제
cap.release()
    
# cv2.imshow("Frame" , frame)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## Droidcam intrinsic parameter

# %%
rms = 0.401862
fx = 488.943879
fy = 490.295543
cx = 323.123703
cy = 240.284288
k1 = 0.067409
k2 = -0.035474
p1 = -0.002333
p2 = -0.001423

# %%
import numpy as np


def detect_corners(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = auto_canny_otsu(gray)
    corners = cv2.goodFeaturesToTrack(edges, maxCorners=100, qualityLevel=0.01, minDistance=30)
    return np.int0(corners)

# %%
frame1 = cv2.imread("./data/droid_calib/checkerboard_0.jpg")
frame2 = cv2.imread("./data/droid_calib/checkerboard_1.jpg")

img1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)

# SIFT로 특징점 검출 및 기술자 생성
sift = cv2.SIFT_create()
keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2, None)

# FLANN 매처를 사용한 특징점 매칭
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)
flann = cv2.FlannBasedMatcher(index_params, search_params)
matches = flann.knnMatch(descriptors1, descriptors2, k=2)

# Lowe의 비율 테스트를 사용하여 좋은 매칭 필터링
good_matches = []
for m, n in matches:
    if m.distance < 0.7 * n.distance:
        good_matches.append(m)

# 삼각 측량을 위한 특징점 좌표 추출
pts1 = np.float32([keypoints1[m.queryIdx].pt for m in good_matches])
pts2 = np.float32([keypoints2[m.trainIdx].pt for m in good_matches])


# 첫 번째 이미지에 특징점 표시
img1_keypoints = cv2.drawKeypoints(img1, keypoints1, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# 두 번째 이미지에 특징점 표시
img2_keypoints = cv2.drawKeypoints(img2, keypoints2, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

img_matches = cv2.drawMatches(img1, keypoints1, img2, keypoints2, good_matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)


# 카메라 내부 매개변수 (예시)
K = np.array([[fx, 0, cx],
              [0, fy, cy],
              [0, 0, 1]])  # f는 초점 거리, cx, cy는 주점 좌표

# 외부 매개변수 (예시)
R = np.eye(3)  # 회전 행렬
t = np.zeros((3, 1))  # 이동 벡터

# 투영 행렬 생성
P1 = np.dot(K, np.hstack((R, t)))
P2 = np.dot(K, np.hstack((R, t + np.array([[1], [0], [0]]))))  # 두 번째 카메라의 위치가 약간 이동했다고 가정

# 삼각 측량 수행
points_4d_hom = cv2.triangulatePoints(P1, P2, pts1.T, pts2.T)

# 동차 좌표에서 일반 좌표로 변환
points_3d = points_4d_hom / points_4d_hom[3]
points_3d = points_3d[:3].T

# 투영 매트릭스
P = np.dot(K, np.hstack((R, t)))

# 3D 점을 2D로 투영
points_2d = cv2.projectPoints(points_3d, R, t, K, None)[0]


# 중심 좌표(0, 0, 0)를 2D로 투영
center_point_3d = np.array([[0.0, 0.0, 0.0]])
center_point_2d = cv2.projectPoints(center_point_3d, R, t, K, None)[0]


# 3D 점을 2D로 투영
points_2d = cv2.projectPoints(points_3d, R, t, K, None)[0]

# 2D 투영 점을 이미지에 표시하고, 해당 점의 3D 좌표를 텍스트로 추가
for i, point in enumerate(points_2d):
    x, y = int(point[0][0]), int(point[0][1])
    cv2.circle(frame1, (x, y), 5, (0, 255, 0), -1)
    
    # 3D 좌표 텍스트로 표시
    text = f"({points_3d[i][0]:.2f}, {points_3d[i][1]:.2f}, {points_3d[i][2]:.2f})"
    cv2.putText(frame1, text, (x + 10, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

x_center, y_center = int(center_point_2d[0][0][0]), int(center_point_2d[0][0][1])
cv2.circle(frame1, (x_center, y_center), 5, (0, 0, 255), -1)
cv2.putText(frame1, "Center (0, 0, 0)", (x_center + 10, y_center), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    
    
# 이미지 표시
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB))
plt.title('Image with 3D Points')
plt.show()

# %%
K = np.array([[fx, 0, cx], [0, fy, cy], [0, 0, 1]])
R = np.eye(3)
t = np.zeros((3, 1))

# 투영 행렬 생성
P1 = np.dot(K, np.hstack((R, t)))
P2 = np.dot(K, np.hstack((R, t + np.array([[1], [0], [0]]))))

cap = cv2.VideoCapture("http://192.168.0.9:4747/video")

_, old_frame = cap.read()
old_gray = cv2.cvtColor(old_frame, cv2.COLOR_BGR2GRAY)
p0 = cv2.goodFeaturesToTrack(old_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)

# Lucas-Kanade 파라미터
lk_params = dict(winSize=(15, 15), maxLevel=2, criteria=(cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # 옵티컬 플로우 계산
    p1, st, err = cv2.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)
#     print(len(p1), len(st))
    # 좋은 코너점 선택
    good_new = p1[st.flatten() == 1]
    good_old = p0[st.flatten() == 1]

    # 삼각측량 수행
    points_4d_hom = cv2.triangulatePoints(P1, P2, good_old.T, good_new.T)
    points_3d = points_4d_hom / points_4d_hom[3]
    points_3d = points_3d[:3].T

    # 3D 점을 2D로 투영
    points_2d = cv2.projectPoints(points_3d, R, t, K, None)[0]

    # 중심 좌표(0, 0, 0)를 2D로 투영
    center_point_3d = np.array([[0.0, 0.0, 0.0]])
    center_point_2d = cv2.projectPoints(center_point_3d, R, t, K, None)[0]
    
#     print(points_3d.shape)
    if len(points_3d.shape) == 3 and points_3d.shape[1] == 1 :
        points_3d = points_3d.reshape(-1, 3)
    
    # 3D 좌표 시각화
    for i, point in enumerate(good_new):
        a, b = point.ravel()
        a, b = int(a), int(b)
        cv2.circle(frame, (a, b), 5, (0, 255, 0), -1)
        
        # 3D 좌표 텍스트로 표시
        if i < len(points_3d):
            text = f"3D: ({points_3d[i][0]:.2f}, {points_3d[i][1]:.2f}, {points_3d[i][2]:.2f})"
            cv2.putText(frame, text, (a + 5, b + 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    
    x_center, y_center = int(center_point_2d[0][0][0]), int(center_point_2d[0][0][1])
    cv2.circle(frame, (x_center, y_center), 5, (0, 0, 255), -1)
    cv2.putText(frame, "Center (0, 0, 0)", (x_center + 10, y_center), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    
    cv2.imshow('Frame with 3D Points', frame)
        
        
    # 새로운 코너점 검출 및 추적
#     print("good new : ",len(good_new))
    p0 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)
#     print("p0 shape:",p0.shape)
#     else :
#         new_p0 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)
#         p0 = good_new.reshape(-1, 1, 2)
    # 다음 반복을 위한 준비
    old_gray = frame_gray.copy()
#     p0 = good_new.reshape(-1, 1, 2)
#     print("goodnew shape",p0.shape)
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\414969436.py:34: RuntimeWarning: overflow encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\414969436.py:34: RuntimeWarning: invalid value encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\414969436.py:34: RuntimeWarning: divide by zero encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]

# %%
cap = cv2.VideoCapture("http://192.168.0.9:4747/video")

_, frame = cap.read()

# %%
frame.shape
# Out:
# (480, 640, 3)

# %%
frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
plt.imshow(frame_gray, cmap='gray')

# %%
def find_edge_and_corners(image) : 
    edges = auto_canny_otsu(image)
    corners = cv2.cornerHarris(edges, 2, 3, 0.04)
    
    y, x = np.nonzero(corners > 0.01 * corners.max())
    points = np.float32([x, y]).T
    
    return points

corners = find_edge_and_corners(frame_gray)
print(corners)
# Out:
# [[  0.   0.]
#  [  1.   0.]
#  [  2.   0.]
#  ...
#  [179. 463.]
#  [180. 463.]
#  [ 97. 464.]]

# %%
edges = auto_canny_otsu(frame_gray)
plt.imshow(edges ,cmap='gray')

# %%
test = frame.copy()
# 코너점 시각화


for corner in corners:
    x, y = corner.ravel()
    x, y = int(x), int(y)
    cv2.circle(test, (x, y), 5, (0, 255, 0), -1)
    
plt.imshow(cv2.cvtColor(test, cv2.COLOR_BGR2RGB))

# %%
test = frame.copy()


p0 = cv2.goodFeaturesToTrack(edges, maxCorners=100, qualityLevel=0.01, minDistance=30)
for corner in p0:
    x, y = corner.ravel()
    x, y = int(x), int(y)
    cv2.circle(test, (x, y), 5, (0, 255, 0), -1)
    
plt.imshow(cv2.cvtColor(test, cv2.COLOR_BGR2RGB))

# %%
K = np.array([[fx, 0, cx], [0, fy, cy], [0, 0, 1]])
R = np.eye(3)
t = np.zeros((3, 1))

# 투영 행렬 생성
P1 = np.dot(K, np.hstack((R, t)))
P2 = np.dot(K, np.hstack((R, t + np.array([[1], [0], [0]]))))

cap = cv2.VideoCapture("http://192.168.0.9:4747/video")

_, old_frame = cap.read()
old_gray = cv2.cvtColor(old_frame, cv2.COLOR_BGR2GRAY)
old_edges = auto_canny_otsu(old_gray)
p0 = cv2.goodFeaturesToTrack(old_edges, maxCorners=100, qualityLevel=0.01, minDistance=30)

# Lucas-Kanade 파라미터
lk_params = dict(winSize=(15, 15), maxLevel=2, criteria=(cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = auto_canny_otsu(old_gray)
    # 옵티컬 플로우 계산
    p1, st, err = cv2.calcOpticalFlowPyrLK(old_edges, edges, p0, None, **lk_params)
#     print(len(p1), len(st))
    # 좋은 코너점 선택
    good_new = p1[st.flatten() == 1]
    good_old = p0[st.flatten() == 1]

    # 삼각측량 수행
    points_4d_hom = cv2.triangulatePoints(P1, P2, good_old.T, good_new.T)
    points_3d = points_4d_hom / points_4d_hom[3]
    points_3d = points_3d[:3].T

    # 3D 점을 2D로 투영
    points_2d = cv2.projectPoints(points_3d, R, t, K, None)[0]

    # 중심 좌표(0, 0, 0)를 2D로 투영
    center_point_3d = np.array([[0.0, 0.0, 0.0]])
    center_point_2d = cv2.projectPoints(center_point_3d, R, t, K, None)[0]
    
#     print(points_3d.shape)
    if len(points_3d.shape) == 3 and points_3d.shape[1] == 1 :
        points_3d = points_3d.reshape(-1, 3)
    
    # 3D 좌표 시각화
    for i, point in enumerate(good_new):
        a, b = point.ravel()
        a, b = int(a), int(b)
        cv2.circle(frame, (a, b), 5, (0, 255, 0), -1)
        
        # 3D 좌표 텍스트로 표시
        if i < len(points_3d):
            text = f"3D: ({points_3d[i][0]:.2f}, {points_3d[i][1]:.2f}, {points_3d[i][2]:.2f})"
            cv2.putText(frame, text, (a + 5, b + 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    
    x_center, y_center = int(center_point_2d[0][0][0]), int(center_point_2d[0][0][1])
    cv2.circle(frame, (x_center, y_center), 5, (0, 0, 255), -1)
    cv2.putText(frame, "Center (0, 0, 0)", (x_center + 10, y_center), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    
    cv2.imshow('Frame with 3D Points', frame)
        
        
    # 새로운 코너점 검출 및 추적
#     print("good new : ",len(good_new))
#     p0 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)
#     print("p0 shape:",p0.shape)
#     else :
#         new_p0 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)
#         p0 = good_new.reshape(-1, 1, 2)
    # 다음 반복을 위한 준비
    old_gray = frame_gray.copy()
    old_edges = edges.copy()
    p0 = cv2.goodFeaturesToTrack(old_edges, maxCorners=100, qualityLevel=0.01, minDistance=30)
#     p0 = good_new.reshape(-1, 1, 2)
#     print("goodnew shape",p0.shape)
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\793224348.py:35: RuntimeWarning: invalid value encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\793224348.py:35: RuntimeWarning: overflow encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]

# %%
K = np.array([[fx, 0, cx], [0, fy, cy], [0, 0, 1]])
R = np.eye(3)
t = np.zeros((3, 1))

# 투영 행렬 생성
P1 = np.dot(K, np.hstack((R, t)))
P2 = np.dot(K, np.hstack((R, t + np.array([[1], [0], [0]]))))

cap = cv2.VideoCapture("http://192.168.0.9:4747/video")

_, old_frame = cap.read()
old_gray = cv2.cvtColor(old_frame, cv2.COLOR_BGR2GRAY)
p0 = cv2.goodFeaturesToTrack(old_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)

# Lucas-Kanade 파라미터
lk_params = dict(winSize=(15, 15), maxLevel=2, criteria=(cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # 옵티컬 플로우 계산
    p1, st, err = cv2.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)
    
    if st is not None:
        
        # 좋은 코너점 선택
        good_new = p1[st.flatten() == 1]
        good_old = p0[st.flatten() == 1]

        # 삼각측량 수행
        points_4d_hom = cv2.triangulatePoints(P1, P2, good_old.T, good_new.T)
        points_3d = points_4d_hom / points_4d_hom[3]
        points_3d = points_3d[:3].T

        # 3D 점을 2D로 투영
        points_2d = cv2.projectPoints(points_3d, R, t, K, None)[0]

        if len(points_3d.shape) == 3 and points_3d.shape[1] == 1 :
            points_3d = points_3d.reshape(-1, 3)
    
    # 중심 좌표(0, 0, 0)를 2D로 투영
    center_point_3d = np.array([[0.0, 0.0, 0.0]])
    center_point_2d = cv2.projectPoints(center_point_3d, R, t, K, None)[0]

    
    
    # 3D 좌표 시각화
    for i, point in enumerate(good_new):
        a, b = point.ravel()
        a, b = int(a), int(b)
        cv2.circle(frame, (a, b), 5, (0, 255, 0), -1)
        
        # 3D 좌표 텍스트로 표시
        if i < len(points_3d):
            text = f"3D: ({points_3d[i][0]:.2f}, {points_3d[i][1]:.2f}, {points_3d[i][2]:.2f})"
            cv2.putText(frame, text, (a + 5, b + 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    
    x_center, y_center = int(center_point_2d[0][0][0]), int(center_point_2d[0][0][1])
    cv2.circle(frame, (x_center, y_center), 5, (0, 0, 255), -1)
    cv2.putText(frame, "Center (0, 0, 0)", (x_center + 10, y_center), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    
    cv2.imshow('Frame with 3D Points', frame)
        
        
    # 새로운 코너점 검출 및 추적
    if len(good_new) < 100:
        new_p0 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100 - len(good_new), qualityLevel=0.01, minDistance=30)
        if new_p0 is not None:
            p0 = np.concatenate((good_new.reshape(-1, 1, 2), new_p0))
        else:
            p0 = good_new.reshape(-1, 1, 2)

    # 다음 반복을 위한 준비
    old_gray = frame_gray.copy()
#     p0 = good_new.reshape(-1, 1, 2)

    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\98797640.py:36: RuntimeWarning: overflow encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\98797640.py:36: RuntimeWarning: invalid value encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\98797640.py:36: RuntimeWarning: divide by zero encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]

# %%
import cv2
import numpy as np

# 카메라 매개변수 설정 
K = np.array([[fx, 0, cx], [0, fy, cy], [0, 0, 1]])
R = np.eye(3)
t = np.zeros((3, 1))

# 투영 행렬 생성
P1 = np.dot(K, np.hstack((R, t)))
P2 = np.dot(K, np.hstack((R, t + np.array([[1], [0], [0]]))))

# 비디오 캡처 설정
cap = cv2.VideoCapture("http://192.168.0.9:4747/video")
_, old_frame = cap.read()
old_gray = cv2.cvtColor(old_frame, cv2.COLOR_BGR2GRAY)

# 초기 코너점 검출
p0 = cv2.goodFeaturesToTrack(old_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)

# Lucas-Kanade 파라미터 설정
lk_params = dict(winSize=(15, 15), maxLevel=2, criteria=(cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 옵티컬 플로우 계산
    p1, st, err = cv2.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)

    # 좋은 코너점 선택
    good_new = p1[st.flatten() == 1]
    good_old = p0[st.flatten() == 1]

    # 삼각측량 수행
    points_4d_hom = cv2.triangulatePoints(P1, P2, good_old.T, good_new.T)
    points_3d = points_4d_hom / points_4d_hom[3]
    points_3d = points_3d[:3].T
    
#     print(points_3d.shape)
    if len(points_3d.shape) == 3 and points_3d.shape[1] == 1 :
            points_3d = points_3d.reshape(-1, 3)
    
    # 3D 좌표 시각화
    for i, point in enumerate(good_new):
        a, b = point.ravel()
        cv2.circle(frame, (int(a), int(b)), 5, (0, 255, 0), -1)
        if i < len(points_3d):
            x3d, y3d, z3d = points_3d[i]
            text = f"3D: ({x3d:.2f}, {y3d:.2f}, {z3d:.2f})"
            cv2.putText(frame, text, (int(a) + 5, int(b) + 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

    cv2.imshow('Frame', frame)

    # 새로운 코너점 검출 및 추적
    if len(good_new) < 100:
        new_p0 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100 - len(good_new), qualityLevel=0.01, minDistance=30)
        if new_p0 is not None:
            good_new_reshaped = good_new.reshape(-1, 1, 2)
            p0 = np.concatenate((good_new_reshaped, new_p0), axis=0)
        else:
            p0 = good_new.reshape(-1, 1, 2)
    else:
        p0 = good_new.reshape(-1, 1, 2)

    old_gray = frame_gray.copy()

    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\2195317129.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\2195317129.py:40: RuntimeWarning: overflow encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\2195317129.py:40: RuntimeWarning: invalid value encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]

# %% [markdown]
# ---

# %% [markdown]
# ## Okay

# %%
K = np.array([[fx, 0, cx], [0, fy, cy], [0, 0, 1]])
R = np.eye(3)
t = np.zeros((3, 1))

# 투영 행렬 생성
P1 = np.dot(K, np.hstack((R, t)))
P2 = np.dot(K, np.hstack((R, t + np.array([[1], [0], [0]]))))

cap = cv2.VideoCapture("http://192.168.0.9:4747/video")

_, old_frame = cap.read()
old_gray = cv2.cvtColor(old_frame, cv2.COLOR_BGR2GRAY)
p0 = cv2.goodFeaturesToTrack(old_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)

# Lucas-Kanade 파라미터
lk_params = dict(winSize=(15, 15), maxLevel=2, criteria=(cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # 옵티컬 플로우 계산
    p1, st, err = cv2.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)
#     print(len(p1), len(st))
    # 좋은 코너점 선택
    good_new = p1[st.flatten() == 1]
    good_old = p0[st.flatten() == 1]

    # 삼각측량 수행
    points_4d_hom = cv2.triangulatePoints(P1, P2, good_old.T, good_new.T)
    points_3d = points_4d_hom / points_4d_hom[3]
    points_3d = points_3d[:3].T

    # 3D 점을 2D로 투영
    points_2d = cv2.projectPoints(points_3d, R, t, K, None)[0]

    # 중심 좌표(0, 0, 0)를 2D로 투영
    center_point_3d = np.array([[0.0, 0.0, 0.0]])
    center_point_2d = cv2.projectPoints(center_point_3d, R, t, K, None)[0]
    
#     print(points_3d.shape)
    if len(points_3d.shape) == 3 and points_3d.shape[1] == 1 :
        points_3d = points_3d.reshape(-1, 3)
    
    # 3D 좌표 시각화
    for i, point in enumerate(good_new):
        a, b = point.ravel()
        a, b = int(a), int(b)
        cv2.circle(frame, (a, b), 5, (0, 255, 0), -1)
        
        # 3D 좌표 텍스트로 표시
        if i < len(points_3d):
            text = f"3D: ({points_3d[i][0]:.2f}, {points_3d[i][1]:.2f}, {points_3d[i][2]:.2f})"
            cv2.putText(frame, text, (a + 5, b + 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    
    x_center, y_center = int(center_point_2d[0][0][0]), int(center_point_2d[0][0][1])
    cv2.circle(frame, (x_center, y_center), 5, (0, 0, 255), -1)
    cv2.putText(frame, "Center (0, 0, 0)", (x_center + 10, y_center), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    
    cv2.imshow('Frame with 3D Points', frame)
        
        
    # 새로운 코너점 검출 및 추적
#     print("good new : ",len(good_new))
    p0 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)
#     print("p0 shape:",p0.shape)
#     else :
#         new_p0 = cv2.goodFeaturesToTrack(frame_gray, maxCorners=100, qualityLevel=0.01, minDistance=30)
#         p0 = good_new.reshape(-1, 1, 2)
    # 다음 반복을 위한 준비
    old_gray = frame_gray.copy()
#     p0 = good_new.reshape(-1, 1, 2)
#     print("goodnew shape",p0.shape)
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\414969436.py:34: RuntimeWarning: overflow encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\414969436.py:34: RuntimeWarning: invalid value encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
# C:\Users\yeseul\AppData\Local\Temp\ipykernel_22924\414969436.py:34: RuntimeWarning: divide by zero encountered in true_divide
#   points_3d = points_4d_hom / points_4d_hom[3]
